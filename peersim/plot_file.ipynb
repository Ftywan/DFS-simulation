# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "exp/1000nodes0.01drop0minD25maxD0.3singleReq0.3add0.3delete-file.csv"
df = pd.read_csv(filename)

# %%
begin = df.iloc[:1, 1:]
end = df.iloc[-1:, 1:]

# %%
plt.bar(np.arange(1000), end.values.tolist()[0], align='center', alpha=0.5)
# plt.xticks(np.arange(1000), range(1000))
plt.xlabel('Node Index')
plt.ylabel('No. of File Chunks')
plt.savefig(f'haha.png', dpi=500)
